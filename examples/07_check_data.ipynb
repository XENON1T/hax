# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Check-what-data-we-have-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Check what data we have</a></div><div class="lev2"><a href="#Introduction-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introduction</a></div><div class="lev2"><a href="#Boilerplate-startup-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Boilerplate startup</a></div><div class="lev2"><a href="#Specify-path-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Specify path</a></div><div class="lev2"><a href="#Using-standard-data-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Using standard data</a></div><div class="lev2"><a href="#What-data-is-there-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>What data is there</a></div><div class="lev1"><a href="#AmBe-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>AmBe</a></div><div class="lev2"><a href="#Co60-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Co60</a></div>

# %% [markdown]
# # Check what data we have
#
# Tunnell, Feburary 2016
#
# This tutorial describes how to use determine what datasets we have.

# %% [markdown]
# ## Introduction

# %% [markdown]
# hax keeps track of the datasets that have been taken.  For XENON100, this is just a CSV file.  For XENON1T, it will be a database.  We're having manpower issues getting XENON100 data reprocessed so this notebook will give you an idea as to which datasets were processed.

# %% [markdown]
# ## Boilerplate startup

# %%
# %run boiler_plate.py
# %matplotlib inline 
hax.init()   # Specify your own data location here, if needed
# Out:
# /home/jelle/anaconda3/envs/pax/lib/python3.4/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %% [markdown]
# ## Using standard data

# %% [markdown]
# We can query for datasets where we know the location of the ROOT file and the dataset is marked 'standard' (i.e. good for analysis).

# %%
query = 'location != "" & category == "standard"'
datasets = hax.runs.datasets.query(query)
datasets
# Out:
#                    name      number raw_data_subfolder       source position  \
# 447   xe100_110207_1015  1102071015             run_10        Cs137      red
# 473   xe100_110210_1100  1102101100             run_10         AmBe    other
# 475   xe100_110210_1412  1102101412             run_10         AmBe    other
# 483   xe100_110211_0532  1102110532             run_10         AmBe    other
# 488   xe100_110211_1650  1102111650             run_10        Cs137      red
# 496   xe100_110216_1055  1102161055             run_10        Cs137      red
# 506   xe100_110223_1107  1102231107             run_10        Cs137      red
# 517   xe100_110303_1040  1103031040             run_10        Cs137      red
# 547   xe100_110315_1246  1103151246             run_10        Cs137      red
# 555   xe100_110317_1132  1103171132             run_10        Cs137      red
# 568   xe100_110321_1058  1103211058             run_10        Cs137      red
# 571   xe100_110323_1114  1103231114             run_10         Co60    black
# 581   xe100_110325_1549  1103251549             run_10        Cs137    black
# 609   xe100_110401_2017  1104012017             run_10        Cs137    white
# 636   xe100_110412_1847  1104121847             run_10        Cs137    black
# 641   xe100_110415_0117  1104150117             run_10         Co60      red
# 649   xe100_110418_1629  1104181629             run_10        Cs137      red
# 667   xe100_110425_1129  1104251129             run_10        Cs137      red
# 681   xe100_110502_1658  1105021658             run_10        Cs137      red
# 696   xe100_110509_1659  1105091659             run_10        Cs137      red
# 716   xe100_110516_1713  1105161713             run_10        Cs137      red
# 722   xe100_110517_1511  1105171511             run_10        Cs137    other
# 725   xe100_110517_1712  1105171712             run_10        Cs137    other
# 738   xe100_110523_1809  1105231809             run_10        Cs137      red
# 758   xe100_110530_1958  1105301958             run_10        Cs137      red
# 773   xe100_110606_1927  1106061927             run_10        Cs137      red
# 791   xe100_110613_1643  1106131643             run_10        Cs137      red
# 792   xe100_110613_1723  1106131723             run_10  Dark Matter    other
# 797   xe100_110614_1026  1106141026             run_10  Dark Matter    other
# 833   xe100_110627_1836  1106271836             run_10        Cs137      red
# ...                 ...         ...                ...          ...      ...
# 1431  xe100_120213_1128  1202131128             run_10  Dark Matter    other
# 1432  xe100_120213_1249  1202131249             run_10        Cs137      red
# 1434  xe100_120213_1350  1202131350             run_10  Dark Matter    other
# 1446  xe100_120215_1813  1202151813             run_10  Dark Matter    other
# 1447  xe100_120216_1838  1202161838             run_10        Cs137      red
# 1455  xe100_120220_1730  1202201730             run_10        Cs137      red
# 1462  xe100_120222_1537  1202221537             run_10  Dark Matter    other
# 1471  xe100_120227_1547  1202271547             run_10        Cs137      red
# 1476  xe100_120228_1440  1202281440             run_10  Dark Matter    other
# 1494  xe100_120305_1651  1203051651             run_10        Cs137      red
# 1527  xe100_120306_1313  1203061313             run_10  Dark Matter    other
# 1529  xe100_120307_1604  1203071604             run_10  Dark Matter    other
# 1545  xe100_120312_1851  1203121851             run_10        Cs137      red
# 1552  xe100_120315_1132  1203151132             run_10  Dark Matter    other
# 1558  xe100_120316_1127  1203161127             run_10  Dark Matter    other
# 1559  xe100_120317_1159  1203171159             run_10  Dark Matter    other
# 1560  xe100_120317_1803  1203171803             run_10  Dark Matter    other
# 1561  xe100_120318_1315  1203181315             run_10  Dark Matter    other
# 1563  xe100_120319_1654  1203191654             run_10        Cs137      red
# 1568  xe100_120320_1122  1203201122             run_10  Dark Matter    other
# 1570  xe100_120322_1230  1203221230             run_10  Dark Matter    other
# 1575  xe100_120324_0903  1203240903             run_10  Dark Matter    other
# 1576  xe100_120325_0846  1203250846             run_10  Dark Matter    other
# 1577  xe100_120326_0952  1203260952             run_10  Dark Matter    other
# 1579  xe100_120326_1615  1203261615             run_10        Cs137      red
# 1584  xe100_120327_0944  1203270944             run_10  Dark Matter    other
# 1593  xe100_120331_1627  1203311627             run_10  Dark Matter    other
# 1594  xe100_120401_0935  1204010935             run_10  Dark Matter    other
# 1596  xe100_120401_2201  1204012201             run_10  Dark Matter    other
# 1614  xe100_120404_0804  1204040804             run_10         AmBe    other
#
#      trigger  anode  cathode  shield    livetime      ...        processed  \
# 447       S1    4.0       16  closed   1811.1800      ...            0.4.5
# 473       S1    4.4       16  closed    202.1600      ...            0.4.5
# 475       S1    4.4       16  closed   2025.0800      ...            0.4.5
# 483       S1    4.4       16  closed   2274.4600      ...            0.4.5
# 488       S1    4.0       16  closed   1774.5000      ...            0.4.5
# 496       S1    2.2       16  closed   1909.3500      ...            0.4.5
# 506       S1    2.2       16  closed   1920.2900      ...            0.4.5
# 517       S1    4.4       16  closed   1390.7100      ...            0.4.5
# 547       S1    4.4       16  closed   1599.9100      ...            0.4.5
# 555       S1    4.4       16  closed   1524.2400      ...            0.4.5
# 568       S1    4.4       16  closed   1297.3400      ...            0.4.5
# 571       S1    4.4       16  closed   1640.8800      ...            0.4.5
# 581       S1    4.4       16  closed   1865.3700      ...            0.4.5
# 609       S1    4.4       16  closed   2025.9000      ...            0.4.5
# 636       S1    4.4       16  closed   2300.3400      ...            0.4.5
# 641       S1    4.4       16  closed     18.7553      ...            0.4.5
# 649       S1    4.4       16  closed   1737.0700      ...            0.4.5
# 667       S1    4.4       16  closed   1803.8600      ...            0.4.5
# 681       S1    4.4       16  closed   1796.4000      ...            0.4.5
# 696       S1    4.4       16  closed   1809.2100      ...            0.4.5
# 716       S1    4.4       16  closed   1744.2300      ...            0.4.5
# 722       S1    4.4       16  closed   3561.2900      ...            0.4.5
# 725       S1    4.4       16  closed   6962.4900      ...            0.4.5
# 738       S1    4.4       16  closed   1791.4700      ...            0.4.5
# 758       S1    4.4       16  closed   1808.0400      ...            0.4.5
# 773       S1    4.4       16  closed   1623.9400      ...            0.4.5
# 791       S1    4.4       16  closed    923.0300      ...            0.4.5
# 792       S1    4.4       16  closed   6532.1600      ...            0.4.5
# 797       S1    4.4       16  closed   3247.5800      ...            0.4.5
# 833       S1    4.4       16  closed   1741.9600      ...            0.4.5
# ...      ...    ...      ...     ...         ...      ...              ...
# 1431      S1    4.4       16  closed   4737.7000      ...            0.4.5
# 1432      S1    4.4       16  closed   1923.6900      ...            0.4.5
# 1434      S1    4.4       16  closed  25244.0000      ...            0.4.5
# 1446      S1    4.4       16  closed  88246.7000      ...            0.4.5
# 1447      S1    4.4       16  closed   1910.5000      ...            0.4.5
# 1455      S1    4.4       16  closed   1962.0200      ...            0.4.5
# 1462      S1    4.4       16  closed  85602.0000      ...            0.4.5
# 1471      S1    4.4       16  closed   1953.1600      ...            0.4.5
# 1476      S1    4.4       16  closed  91870.1000      ...            0.4.5
# 1494      S1    4.4       16  closed   1945.2600      ...            0.4.5
# 1527      S1    4.4       16  closed   9842.0000      ...            0.4.5
# 1529      S1    4.4       16  closed  14698.7000      ...            0.4.5
# 1545      S1    4.4       16  closed   1973.3100      ...            0.4.5
# 1552      S1    4.4       16  closed  27251.1000      ...            0.4.5
# 1558      S1    4.4       16  closed  88755.8000      ...            0.4.5
# 1559      S1    4.4       16  closed  19182.8000      ...            0.4.5
# 1560      S1    4.4       16  closed  68664.0000      ...            0.4.5
# 1561      S1    4.4       16  closed  96337.5000      ...            0.4.5
# 1563      S1    4.4       16  closed   1992.6000      ...            0.4.5
# 1568      S1    4.4       16  closed  85758.1000      ...            0.4.5
# 1570      S1    4.4       16  closed  21944.5000      ...            0.4.5
# 1575      S1    4.4       16  closed  82185.6000      ...            0.4.5
# 1576      S1    4.4       16  closed  90780.2000      ...            0.4.5
# 1577      S1    4.4       16  closed  20983.4000      ...            0.4.5
# 1579      S1    4.4       16  closed   1956.5900      ...            0.4.5
# 1584      S1    4.4       16  closed  84414.8000      ...            0.4.5
# 1593      S1    4.4       16  closed  61753.7000      ...            0.4.5
# 1594      S1    4.4       16  closed  38028.9000      ...            0.4.5
# 1596      S1    4.4       16  closed  39603.3000      ...            0.4.5
# 1614      S1    4.4       16  closed    843.9120      ...            0.4.5
#
#       category                                            comment Unnamed: 16  \
# 447   standard  Trigger 60/51, holdoff 1ms, PMT 177 Off, PMT89...         NaN
# 473   standard  Trg 60/51, holdoff 1ms, HE veto (2x10dB/4/100/40)         NaN
# 475   standard  Trg 60/51, holdoff 1ms, HE veto (2x10dB/4/100/40)         NaN
# 483   standard  Trg 60/51, holdoff 1ms, HE veto (2x10dB/4/100/40)         NaN
# 488   standard                         Trigger 60/51, holdoff 1ms         NaN
# 496   standard                         Trigger 60/51, holdoff 1ms         NaN
# 506   standard                         Trigger 60/51, holdoff 1ms         NaN
# 517   standard                         Trigger 60/51, holdoff 1ms         NaN
# 547   standard                         Trigger 60/51, holdoff 1ms         NaN
# 555   standard                         Trigger 60/51, holdoff 1ms         NaN
# 568   standard                         Trigger 60/51, holdoff 1ms         NaN
# 571   standard    Maj Trigger 60/51. He veto ON raw 120 shaped 40         NaN
# 581   standard                         Trigger 60/51, holdoff 1ms         NaN
# 609   standard                         Trigger 60/51, holdoff 1ms         NaN
# 636   standard                         Trigger 60/51, holdoff 1ms         NaN
# 641   standard    Maj Trigger 60/51. He veto ON raw 120 shaped 40         NaN
# 649   standard                         Trigger 60/51, holdoff 1ms         NaN
# 667   standard                         Trigger 60/51, holdoff 1ms         NaN
# 681   standard                         Trigger 60/51, holdoff 1ms         NaN
# 696   standard                         Trigger 60/51, holdoff 1ms         NaN
# 716   standard                         Trigger 60/51, holdoff 1ms         NaN
# 722   standard  Trigger 60/51, holdoff 1ms, 0.74kBq source (Cs...         NaN
# 725   standard  Trigger 60/51, holdoff 1ms, 0.74kBq source (Cs...         NaN
# 738   standard                         Trigger 60/51, holdoff 1ms         NaN
# 758   standard                         Trigger 60/51, holdoff 1ms         NaN
# 773   standard                         Trigger 60/51, holdoff 1ms         NaN
# 791   standard                                                NaN         NaN
# 792   standard                                                NaN         NaN
# 797   standard  ERROR: CAENVME_FIFOBLTReadCycle Error::: Modul...         NaN
# 833   standard                                                NaN         NaN
# ...        ...                                                ...         ...
# 1431  standard                                                NaN         NaN
# 1432  standard                                                NaN         NaN
# 1434  standard                                                NaN         NaN
# 1446  standard                                                NaN         NaN
# 1447  standard                                                NaN         NaN
# 1455  standard                                                NaN         NaN
# 1462  standard                                                NaN         NaN
# 1471  standard                                                NaN         NaN
# 1476  standard                                                NaN         NaN
# 1494  standard                                                NaN         NaN
# 1527  standard                                                NaN         NaN
# 1529  standard                                                NaN         NaN
# 1545  standard                                                NaN         NaN
# 1552  standard                                                NaN         NaN
# 1558  standard                                                NaN         NaN
# 1559  standard                                                NaN         NaN
# 1560  standard                                                NaN         NaN
# 1561  standard                                                NaN         NaN
# 1563  standard                                                NaN         NaN
# 1568  standard                                                NaN         NaN
# 1570  standard                                                NaN         NaN
# 1575  standard                                                NaN         NaN
# 1576  standard                                                NaN         NaN
# 1577  standard                                                NaN         NaN
# 1579  standard                                                NaN         NaN
# 1584  standard                                                NaN         NaN
# 1593  standard                                                NaN         NaN
# 1594  standard                                                NaN         NaN
# 1596  standard                                                NaN         NaN
# 1614  standard                                                NaN         NaN
#
#      Unnamed: 17 Unnamed: 18 run       tpc  \
# 447          NaN         NaN  10  xenon100
# 473          NaN         NaN  10  xenon100
# 475          NaN         NaN  10  xenon100
# 483          NaN         NaN  10  xenon100
# 488          NaN         NaN  10  xenon100
# 496          NaN         NaN  10  xenon100
# 506          NaN         NaN  10  xenon100
# 517          NaN         NaN  10  xenon100
# 547          NaN         NaN  10  xenon100
# 555          NaN         NaN  10  xenon100
# 568          NaN         NaN  10  xenon100
# 571          NaN         NaN  10  xenon100
# 581          NaN         NaN  10  xenon100
# 609          NaN         NaN  10  xenon100
# 636          NaN         NaN  10  xenon100
# 641          NaN         NaN  10  xenon100
# 649          NaN         NaN  10  xenon100
# 667          NaN         NaN  10  xenon100
# 681          NaN         NaN  10  xenon100
# 696          NaN         NaN  10  xenon100
# 716          NaN         NaN  10  xenon100
# 722          NaN         NaN  10  xenon100
# 725          NaN         NaN  10  xenon100
# 738          NaN         NaN  10  xenon100
# 758          NaN         NaN  10  xenon100
# 773          NaN         NaN  10  xenon100
# 791          NaN         NaN  10  xenon100
# 792          NaN         NaN  10  xenon100
# 797          NaN         NaN  10  xenon100
# 833          NaN         NaN  10  xenon100
# ...          ...         ...  ..       ...
# 1431         NaN         NaN  10  xenon100
# 1432         NaN         NaN  10  xenon100
# 1434         NaN         NaN  10  xenon100
# 1446         NaN         NaN  10  xenon100
# 1447         NaN         NaN  10  xenon100
# 1455         NaN         NaN  10  xenon100
# 1462         NaN         NaN  10  xenon100
# 1471         NaN         NaN  10  xenon100
# 1476         NaN         NaN  10  xenon100
# 1494         NaN         NaN  10  xenon100
# 1527         NaN         NaN  10  xenon100
# 1529         NaN         NaN  10  xenon100
# 1545         NaN         NaN  10  xenon100
# 1552         NaN         NaN  10  xenon100
# 1558         NaN         NaN  10  xenon100
# 1559         NaN         NaN  10  xenon100
# 1560         NaN         NaN  10  xenon100
# 1561         NaN         NaN  10  xenon100
# 1563         NaN         NaN  10  xenon100
# 1568         NaN         NaN  10  xenon100
# 1570         NaN         NaN  10  xenon100
# 1575         NaN         NaN  10  xenon100
# 1576         NaN         NaN  10  xenon100
# 1577         NaN         NaN  10  xenon100
# 1579         NaN         NaN  10  xenon100
# 1584         NaN         NaN  10  xenon100
# 1593         NaN         NaN  10  xenon100
# 1594         NaN         NaN  10  xenon100
# 1596         NaN         NaN  10  xenon100
# 1614         NaN         NaN  10  xenon100
#
#                                                location raw_data_found
# 447   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 473   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 475   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 483   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 488   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 496   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 506   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 517   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 547   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 555   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 568   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 571   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 581   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 609   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 636   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 641   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 649   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 667   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 681   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 696   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 716   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 722   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 725   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 738   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 758   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 773   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 791   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 792   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 797   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 833   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# ...                                                 ...            ...
# 1431  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1432  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1434  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1446  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1447  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1455  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1462  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1471  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1476  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1494  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1527  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1529  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1545  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1552  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1558  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1559  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1560  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1561  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1563  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1568  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1570  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1575  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1576  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1577  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1579  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1584  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1593  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1594  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1596  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1614  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
#
# [189 rows x 23 columns]

# %% [markdown]
# ## What data is there
#
# Here you can see what types of data are processed.

# %%
datasets['source'].unique()
# Out:
# array(['Cs137', 'AmBe', 'Co60', 'Dark Matter'], dtype=object)

# %% [markdown]
# # AmBe
#
# These are very important for analysis.  Let's make a run list:

# %%
datasets[datasets['source'] == 'AmBe']
# Out:
#                    name      number raw_data_subfolder source position  \
# 473   xe100_110210_1100  1102101100             run_10   AmBe    other
# 475   xe100_110210_1412  1102101412             run_10   AmBe    other
# 483   xe100_110211_0532  1102110532             run_10   AmBe    other
# 1614  xe100_120404_0804  1204040804             run_10   AmBe    other
#
#      trigger  anode  cathode  shield  livetime      ...        processed  \
# 473       S1    4.4       16  closed   202.160      ...            0.4.5
# 475       S1    4.4       16  closed  2025.080      ...            0.4.5
# 483       S1    4.4       16  closed  2274.460      ...            0.4.5
# 1614      S1    4.4       16  closed   843.912      ...            0.4.5
#
#       category                                            comment Unnamed: 16  \
# 473   standard  Trg 60/51, holdoff 1ms, HE veto (2x10dB/4/100/40)         NaN
# 475   standard  Trg 60/51, holdoff 1ms, HE veto (2x10dB/4/100/40)         NaN
# 483   standard  Trg 60/51, holdoff 1ms, HE veto (2x10dB/4/100/40)         NaN
# 1614  standard                                                NaN         NaN
#
#      Unnamed: 17 Unnamed: 18 run       tpc  \
# 473          NaN         NaN  10  xenon100
# 475          NaN         NaN  10  xenon100
# 483          NaN         NaN  10  xenon100
# 1614         NaN         NaN  10  xenon100
#
#                                                location raw_data_found
# 473   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 475   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 483   /mnt/xecluster/archive_lngs/common/PaxReproces...           True
# 1614  /mnt/xecluster/archive_lngs/common/PaxReproces...           True
#
# [4 rows x 23 columns]

# %% [markdown]
# ## Co60
#
# Let's make a list of the datasets.

# %%
datasets_co60 = datasets[datasets['source'] == 'Co60']['name'].values
datasets_co60
# Out:
# array(['xe100_110323_1114', 'xe100_110415_0117'], dtype=object)

# %% [markdown]
# But this wasn't too helpful since it's a `numpy` array.  Let's have a list instead.

# %%
list(datasets_co60)
# Out:
# ['xe100_110323_1114', 'xe100_110415_0117']
